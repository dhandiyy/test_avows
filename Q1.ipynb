# %%
import numpy as np
import csv
import pandas as pd
import matplotlib as mb

data = pd.read_csv('owid-covid-data.csv')
data.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
data_France_March = data[(data['location'] == 'France') & (data['date'].str.contains("03"))]
data_France_March.tail()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 79201      FRA    Europe   France  2022-09-03   34626425.0        0.0
# 79231      FRA    Europe   France  2022-10-03   35546188.0    92739.0
# 79262      FRA    Europe   France  2022-11-03   36952950.0    42025.0
# 79292      FRA    Europe   France  2022-12-03   38014872.0        0.0
# 79323      FRA    Europe   France  2023-01-03   39396172.0    23012.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 79201           16790.143      154258.0         0.0               47.429  ...
# 79231           45639.143      155267.0        86.0               34.000  ...
# 79262           20853.000      157268.0        55.0               61.143  ...
# 79292           54829.000      159162.0         0.0               64.857  ...
# 79323           19489.143      162446.0       163.0              114.571  ...
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
print(data_France_March['median_age'].unique())
print(data_France_March['aged_65_older'].unique())
print(data_France_March['aged_70_older'].unique())
# Out:
# [42.]
# [19.718]
# [13.079]

# %% [markdown]
# # Answers for Q1
